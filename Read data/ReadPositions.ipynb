# %%
# !pip3 install rdkit
# pip3 install biopandas

# %%
from rdkit import Chem
import os
from biopandas.mol2 import PandasMol2

# %%
directory = 'mol2files_gaff'
 
files = []
# iterate over files in directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    files.append(f)

# %%
pmol = PandasMol2().read_mol2(files[0])

# %%
print('Molecule ID: %s' % pmol.code)
# print('\nRaw MOL2 file contents:\n\n%s\n...' % pmol.mol2_text)
pmol.df
# Out:
# Molecule ID: hexyl
#     atom_id atom_name      x      y      z atom_type  subst_id subst_name  \
# 0         1        C1  1.756 -1.390  0.892        c3         1        MOL
# 1         2        C2  1.158 -1.870  2.206        c3         1        MOL
# 2         3        C3 -0.123 -1.107  2.546        c3         1        MOL
# 3         4        C4 -0.766 -1.552  3.862        c3         1        MOL
# 4         5        C5 -2.046 -0.790  4.202        c3         1        MOL
# 5         6        C6 -2.648 -1.267  5.517        c3         1        MOL
# 6         7        O1 -3.830 -0.524  5.778        os         1        MOL
# 7         8        C7 -4.490 -0.840  6.933         c         1        MOL
# 8         9        O2 -4.154 -1.692  7.744         o         1        MOL
# 9        10        C8 -5.710  0.020  7.076        c3         1        MOL
# 10       11        H1  2.671 -1.948  0.666        hc         1        MOL
# 11       12        H2  1.055 -1.538  0.064        hc         1        MOL
# 12       13        H3  2.010 -0.327  0.941        hc         1        MOL
# 13       14        H4  1.895 -1.736  3.006        hc         1        MOL
# 14       15        H5  0.953 -2.942  2.125        hc         1        MOL
# 15       16        H6 -0.846 -1.213  1.728        hc         1        MOL
# 16       17        H7  0.108 -0.037  2.624        hc         1        MOL
# 17       18        H8 -0.036 -1.401  4.667        hc         1        MOL
# 18       19        H9 -0.975 -2.628  3.823        hc         1        MOL
# 19       20       H10 -2.792 -0.909  3.408        hc         1        MOL
# 20       21       H11 -1.841  0.286  4.266        hc         1        MOL
# 21       22       H12 -2.908 -2.329  5.464        h1         1        MOL
# 22       23       H13 -1.950 -1.112  6.346        h1         1        MOL
# 23       24       H14 -6.565 -0.469  6.603        hc         1        MOL
# 24       25       H15 -5.529  0.999  6.626        hc         1        MOL
# 25       26       H16 -5.932  0.161  8.137        hc         1        MOL
#
#     charge
# 0  -0.0933
# 1  -0.0815
# 2  -0.0791
# 3  -0.0754
# 4  -0.1163
# 5   0.1398
# 6  -0.4614
# 7   0.6377
# 8  -0.5139
# 9  -0.1618
# 10  0.0329
# 11  0.0329
# 12  0.0329
# 13  0.0378
# 14  0.0378
# 15  0.0437
# 16  0.0437
# 17  0.0414
# 18  0.0414
# 19  0.0503
# 20  0.0503
# 21  0.0673
# 22  0.0673
# 23  0.0751
# 24  0.0751
# 25  0.0751
